# %% [markdown]
# # Your Notebook!
#
# ###  I would recommend using some of the following functions to start things off.
#
# * NSSP_Element_Grabber(data, Timed=True, Priority_only=False, outfile='None')
# * timeliness_facvisits_hours(data, Timed=False)
# * priority_cols(df, priority='both', extras=None, drop_cols=None)
# * completeness_facvisits(df, Timed=False)
# * issues_in_messages(
#     df,
#     Timed=True,
#     combine_issues_on_message=False,
#     split_issue_column=False
# )
# * Visualize_Facility_DQ(df, fac_name, hide_yticks=False, Timed=True)

# %% [markdown]
# --------------
#
# <center> I know its not much but its the best I can do.  </center>
#
# <center>  My gift was my code, and this ones for you.  </center>
#
# <center>  And you can tell everyone, this is your notebook.  </center>
#
# <center>  It may be quite simple, but now that I'm done.  </center>
#
# <center>  I hope you dont mind, I hope you don't mind that I wrote down some tips.  </center>
#
# <center>  How wonderful life is when your coding here.  </center>
#
# -------------

# %%
# Import some data
data = pd.read_csv('../data/raw/YOURFILENAME.csv', encoding = 'Cp1252')

# %%
# Experiment!

# %% [markdown]
# "Yours is the sweetest code....I've ever seen."
#
# ![elton%20john.jpg](attachment:elton%20john.jpg)
